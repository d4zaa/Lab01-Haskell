-- %%
--incrementarLista xs = map suma xs

incrementarLista = map (\x -> x+1)
incrementarLista [3,4,2,1]
-- Out:
-- Line 3: Avoid lambda using `infix`
-- Found:
-- (\ x -> x + 1)
-- Why not:
-- (+ 1)
-- [4,5,3,2]

-- %%
--filtrarPares xs = filter even xs

filtrarPares = filter (\x -> x `mod` 2 == 1)
filtrarPares [1, 2, 4, 3, 8]
-- Out:
-- [1,3]

-- %%
--sumarTuplas xs = ...

sumarTuplas = map (\(a,b) -> a+b)
sumarTuplas [(2,3), (4,1)]
-- Out:
-- Line 3: Use uncurry
-- Found:
-- \ (a, b) -> a + b
-- Why not:
-- uncurry (+)
-- [5,5]

-- %% [markdown]
-- --RETROSPECTIVA--
-- 1. 2 horas 20 minutos - 150 minutos
-- 2. Finalizado
-- 3. Lograr implementar las soluciones sin apoyarme en casi nada de la IA, en parte me demuestra que estoy aprendiendo el lenguaje
-- 4. La sintaxis en algunos problemas. Lo solucione consultando con el profesor
-- 5. Pensar en conjunto como solucionar algun pequeño obstaculo que nos estaba dificultando la solucion. Comprometemos a pensar en conjunto, sin explicitamente ser un simple copia y pega de la solucion del otro
-- 6. http://aprendehaskell.es/main.html
