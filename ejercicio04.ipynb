-- %%
-- [2, 4, 6, 8, 10], porque lo que hace el comando es duplicar el valor en la lista, para los primeros 5 generados 
--en el rango

take 5 (map (*2) [1..])
-- no genera un ciclo infinito por lo explicado anteriormente. Como haskell es perezoso, el 'take 5' solo pide 
-- que se generen/tomen los primeros 5 elementos de ese rango infinito, impidiendo un bucle
-- Out:
-- [2,4,6,8,10]

-- %%
--misterio x y = if x > 10 then y * 2 else x + y

--misterio (5+7) (4*3)
--se calculan los valores a pasar como parametros

--misterio 12 12
--se checkea que condicion se cumple. En este caso, el primer parametro (x = 12) es mayor a 10, por lo que se
--ejecuta la primera; el segundo parametro (y = 12) multiplicado por 2

--24

--probar:
misterio x y = if x > 10 then y * 2 else x + y
misterio (5+7) (4*3)
-- Out:
-- 24
